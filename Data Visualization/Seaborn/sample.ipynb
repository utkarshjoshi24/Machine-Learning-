# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from seaborn) (2.5.0)
# Requirement already satisfied: pandas>=1.2 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/utkarshjoshi/Desktop/Utkarsh Joshi/Data Science with Machine Learning/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd

tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

### Scatter Plot
sns.scatterplot(x="total_bill", y="tip", data = tips)
plt.title("Scatter Plot: Tip v/s Total_Bill")
plt.show()

# %%
### Line Plot

sns.lineplot(x="size", y="total_bill", data = tips)
plt.title("Line Plot")
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
### Bar Plot

sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Bar Plot")
# Out:
# Text(0.5, 1.0, 'Bar Plot')

# %%
### Box Plot

sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("Box Plot")
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
### Violin Plot

sns.violinplot(x="day", y="total_bill", data=tips)
plt.title("Violin Plot")
# Out:
# Text(0.5, 1.0, 'Violin Plot')

# %%
### Histograms

sns.histplot(tips["total_bill"], bins=10, kde=True)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
### KDE Plpt

sns.kdeplot(tips["total_bill"], fill=True)
plt.title("KDE Plot")
# Out:
# Text(0.5, 1.0, 'KDE Plot')

# %%
### Pair Plot

sns.pairplot(tips)

# %%
### Heatmap

corr = tips[["total_bill", "tip", "size"]].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Heat Map")
# Out:
# Text(0.5, 1.0, 'Heat Map')

# %%
### Customized Plot


sales_df = pd.read_csv("ecommerce_sales_1000_records.csv")
sales_df.head(5)

plt.figure(figsize=(10,6))
sns.barplot(x="City", y="Price", data = sales_df, estimator=sum)
# Out:
# <Axes: xlabel='City', ylabel='Price'>
